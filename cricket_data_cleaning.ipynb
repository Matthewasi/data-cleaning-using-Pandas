# %%
#https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
#import necessary lib.
import pandas as pd

# %%
#Load Data as import data (CSV)

# %%
df=pd.read_csv(r"C:\\Users\\Akolgo Matthew Asi\\Desktop\\10Alytics\\espn.csv")

# %%
df.head()
# Out:
#               Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1     AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2    RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3    GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4  H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  55.68    5   4  2  186   5
# 2  54.48    7  11  1  246  11
# 3  56.00   10   5  2  104   1
# 4  34.59   16  23  2  202   6

# %%
# Rename Multiple columns in a list

# %%
df = df.rename(columns={'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#               Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1     AC Voges (AUS)  2015-2016       20    31         7  1485
# 2    RG Pollock (SA)  1963-1970       23    41         4  2256
# 3    GA Headley (WI)  1930-1954       22    40         4  2190
# 4  H Sutcliffe (ENG)  1924-1935       54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.60   29  13  7  626
# 1               269*  61.87        2667                55.68    5   4  2  186
# 2                274  60.97       1707+                54.48    7  11  1  246
# 3               270*  60.83        416+                56.00   10   5  2  104
# 4                194  60.73       6558+                34.59   16  23  2  202
#
#    6s
# 0   6
# 1   5
# 2  11
# 3   1
# 4   6

# %%
#Checking for Null Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
# Checking for Duplicates before Dropping them

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
#Split up span into Start and End Date + Career Lenght

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-').str[0]
# Out:
# 0     1928
# 1     2015
# 2     1963
# 3     1930
# 4     1924
#       ...
# 57    1965
# 58    2002
# 59    1924
# 60    1930
# 61    1928
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year']= df['Span'].str.split(pat='-').str[0].astype('int')

# %%
df['Final_Year']= df['Span'].str.split(pat='-').str[1].astype('int')

# %%
df.head()
# Out:
#               Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1     AC Voges (AUS)  2015-2016       20    31         7  1485
# 2    RG Pollock (SA)  1963-1970       23    41         4  2256
# 3    GA Headley (WI)  1930-1954       22    40         4  2190
# 4  H Sutcliffe (ENG)  1924-1935       54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.60   29  13  7  626
# 1               269*  61.87        2667                55.68    5   4  2  186
# 2                274  60.97       1707+                54.48    7  11  1  246
# 3               270*  60.83        416+                56.00   10   5  2  104
# 4                194  60.73       6558+                34.59   16  23  2  202
#
#    6s  Rookie_Year  Final_Year
# 0   6         1928        1948
# 1   5         2015        2016
# ...

# %%
df.head(2)
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    AC Voges (AUS)  2015-2016       20    31         7  1485
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.60   29  13  7  626
# 1               269*  61.87        2667                55.68    5   4  2  186
#
#    6s  Rookie_Year  Final_Year
# 0   6         1928        1948
# 1   5         2015        2016

# %%
#Drop Span Column

# %%
df=df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 2    RG Pollock (SA)       23    41         4  2256                274  60.97
# 3    GA Headley (WI)       22    40         4  2190               270*  60.83
# 4  H Sutcliffe (ENG)       54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0       9800+                58.60   29  13  7  626   6         1928
# 1        2667                55.68    5   4  2  186   5         2015
# 2       1707+                54.48    7  11  1  246  11         1963
# 3        416+                56.00   10   5  2  104   1         1930
# 4       6558+                34.59   16  23  2  202   6         1924
#
#    Final_Year
# 0        1948
# 1        2016
# 2        1970
# 3        1954
# ...

# %%
#Split the country from the player

# %%
df['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 4     [H Sutcliffe , ENG)]
#               ...
# 57     [KD Walters , AUS)]
# 58    [GC Smith , ICC/SA)]
# 59    [WH Ponsford , AUS)]
# 60      [SJ McCabe , AUS)]
# 61     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]
df['Country'].str.split(pat=')')
# Out:
# 0        [AUS, ]
# 1        [AUS, ]
# 2         [SA, ]
# 3         [WI, ]
# 4        [ENG, ]
#          ...
# 57       [AUS, ]
# 58    [ICC/SA, ]
# 59       [AUS, ]
# 60       [AUS, ]
# 61       [ENG, ]
# Name: Country, Length: 62, dtype: object

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]
df['Country'].str.split(pat='(')
# Out:
# 0        [AUS]
# 1        [AUS]
# 2         [SA]
# 3         [WI]
# 4        [ENG]
#         ...
# 57       [AUS]
# 58    [ICC/SA]
# 59       [AUS]
# 60       [AUS]
# 61       [ENG]
# Name: Country, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                334  99.94
# 1     AC Voges        20    31         7  1485               269*  61.87
# 2   RG Pollock        23    41         4  2256                274  60.97
# 3   GA Headley        22    40         4  2190               270*  60.83
# 4  H Sutcliffe        54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0       9800+                58.60   29  13  7  626   6         1928
# 1        2667                55.68    5   4  2  186   5         2015
# 2       1707+                54.48    7  11  1  246  11         1963
# 3        416+                56.00   10   5  2  104   1         1930
# 4       6558+                34.59   16  23  2  202   6         1924
#
#    Final_Year Country
# 0        1948     AUS
# 1        2016     AUS
# 2        1970      SA
# ...

# %%
#Changing datatypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat='*').str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].str.split(pat='*').str[0]

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
#Remove row 56 (Hon.FS Jackson (ENG))

# %%
df.drop(56,axis=0)
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1      AC Voges        20    31         7  1485                 269  61.87
# 2    RG Pollock        23    41         4  2256                 274  60.97
# 3    GA Headley        22    40         4  2190                 270  60.83
# 4   H Sutcliffe        54    84         9  4555                 194  60.73
# ..           ...      ...   ...       ...   ...                 ...    ...
# 57   KD Walters        74   125        14  5357                 250  48.26
# 58     GC Smith       117   205        13  9265                 277  48.25
# 59  WH Ponsford        29    48         4  2122                 266  48.22
# 60    SJ McCabe        39    62         5  2748                 232  48.21
# 61   DR Jardine        22    33         6  1296                 127  48.00
#
# ...

# %%
df['Balls_Faced']=df['Balls_Faced'].str.split(pat="+").str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].apply(lambda x: int(x) if x.isdigit() else None)

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced            float64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
#calculate with the dataframe
#1. Build a career length column([Final_year]-[rookie_year])

# %%
df['Career_Length']=df['Final_Year']-df['Rookie_Year']

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                 334  99.94
# 1     AC Voges        20    31         7  1485                 269  61.87
# 2   RG Pollock        23    41         4  2256                 274  60.97
# 3   GA Headley        22    40         4  2190                 270  60.83
# 4  H Sutcliffe        54    84         9  4555                 194  60.73
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0         9800                58.60   29  13  7  626   6         1928
# 1         2667                55.68    5   4  2  186   5         2015
# 2         1707                54.48    7  11  1  246  11         1963
# 3          416                56.00   10   5  2  104   1         1930
# 4         6558                34.59   16  23  2  202   6         1924
#
#    Final_Year Country  Career_Length
# 0        1948     AUS             20
# ...

# %%
#2. crickets in this DF what is the average career length

# %%
df['Career_Length'].mean()
# Out:
# 13.209677419354838

# %%
#3. Avarage Battling_strike_rate for cricketers who played over 10 years

# %%
df[df['Career_Length']>10]['Batting_Strike_Rate'].mean()
# Out:
# 47.95113636363636

# %%
#4. Find the number of cricketers who played before 1960

# %%
df[df['Rookie_Year']<1960]['Player'].count()
# Out:
# 23

# %%
#5. Max highest Inns Scores by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int32

# %%
#6. Hundreds, Fifties,ducks(0) average by country

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.538462  21.076923   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
